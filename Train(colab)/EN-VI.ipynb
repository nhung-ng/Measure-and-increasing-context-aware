# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Thesis
# Out:
# /content/drive/MyDrive/Thesis

# %%
# !git clone -b v0.10.2 https://github.com/pytorch/fairseq
# !pip3 install ./fairseq/
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing ./fairseq
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 151 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 92 kB 13.8 MB/s
# ...
#      |████████████████████████████████| 117 kB 52.6 MB/s
# ...
#      |████████████████████████████████| 79 kB 10.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 67.8 MB/s
# ...

# %%
# !pip install sacrebleu==1.5.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 54 kB 2.0 MB/s
# ...
#   Attempting uninstall: portalocker
#     Found existing installation: portalocker 2.4.0
#     Uninstalling portalocker-2.4.0:
#       Successfully uninstalled portalocker-2.4.0
#   Attempting uninstall: sacrebleu
#     Found existing installation: sacrebleu 2.1.0
#     Uninstalling sacrebleu-2.1.0:
#       Successfully uninstalled sacrebleu-2.1.0
# ...

# %%
# %cd contextual-mt/
# Out:
# /content/drive/MyDrive/Thesis/contextual-mt

# %%
# !pip3 install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/Thesis/contextual-mt
# ...
#   Running setup.py develop for contextual-mt
# ...

# %%
# !bash mkdir.sh
# Out:
# mkdir prep bin ...
# mkdir done !!

# %%
# !pip install sentencepiece
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.2 MB 5.0 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 4.7 MB/s
# ...

# %%
# !bash preprocess_phomt.sh
# !bash preprocess_pretrained.sh
# !bash preprocess.sh

# %%
# !bash preprocess.sh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# building sentencepiece model...
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: projects/tir1/corpora/dialogue_mt/iwslt2015/en-vi/train.en-vi.en
#   input_format:
#   model_prefix: projects/tir1/corpora/dialogue_mt/iwslt2015/en-vi/prep/spm.en
#   model_type: BPE
#   vocab_size: 20000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
# ...

# %%
# !bash train.sh
# !bash train_pretrained.sh
# Out:
# 2022-06-24 00:46:00 | INFO | fairseq_cli.train | Namespace(activation_dropout=0.0, activation_fn='relu', adam_betas='(0.9, 0.98)', adam_eps=1e-08, adaptive_input=False, adaptive_softmax_cutoff=None, adaptive_softmax_dropout=0, all_gather_list_size=16384, arch='contextual_transformer', attention_dropout=0.0, batch_size=None, batch_size_valid=None, best_checkpoint_metric='bleu', bf16=False, bpe=None, break_tag='<brk>', broadcast_buffers=False, bucket_cap_mb=25, checkpoint_shard_count=1, checkpoint_suffix='', clip_norm=0.1, context_loss=False, coword_dropout=0.2, coword_dropout_type='sample', cpu=False, criterion='label_smoothed_cross_entropy', cross_self_attention=False, curriculum=0, data='projects/tir1/corpora/dialogue_mt/iwslt2015/en-vi/bin', data_buffer_size=10, dataset_impl=None, ddp_backend='c10d', decoder_attention_heads=8, decoder_embed_dim=512, decoder_embed_path=None, decoder_ffn_embed_dim=2048, decoder_input_dim=512, decoder_layerdrop=0, decoder_layers=6, decoder_layers_to_k
# ...

# %%
# !pip install sentencepiece

# %%
# !data=projects/tir1/corpora/dialogue_mt/iwslt2015/en-vi
# !cp projects/tir1/corpora/dialogue_mt/iwslt2015/en-vi/prep/dict.en.txt projects/tir1/corpora/dialogue_mt/iwslt2015/en-vi/prep/spm.en.model /content/drive/MyDrive/Thesis/contextual-mt/checkpoint
# !cp projects/tir1/corpora/dialogue_mt/iwslt2015/en-vi/prep/dict.vi.txt projects/tir1/corpora/dialogue_mt/iwslt2015/en-vi/prep/spm.vi.model /content/drive/MyDrive/Thesis/contextual-mt/checkpoint

# %%
# !bash cxmi.sh

# %%
# !bash inference.sh
